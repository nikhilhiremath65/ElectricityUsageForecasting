# %%
import numpy as np
import pandas as pd
from scipy import interpolate
from datetime import datetime

# %%
df = pd.read_csv('/home/obin/Desktop/Project/Dataset/Electrical/HomeF/2016/HomeF-meter3_2016.csv')

# %%
df.shape
# Out:
# (503925, 10)

# %%
df
# Out:
#                   Date_Time     Usage  Generation  Net_Meter      Volt  \
# 0       2016-01-01 00:00:00  0.404217    0.009483   0.413700  0.002167
# 1       2016-01-01 00:01:00  0.338933    0.009200   0.348133  0.002133
# 2       2016-01-01 00:02:00  0.402850    0.009133   0.411983  0.002167
# 3       2016-01-01 00:03:00  0.530683    0.009883   0.540567  0.002133
# 4       2016-01-01 00:04:00  1.654650    0.010483   1.665133  0.002133
# 5       2016-01-01 00:05:00  1.155783    0.011317   1.167100  0.002133
# 6       2016-01-01 00:06:00  0.430100    0.008883   0.438983  0.002167
# 7       2016-01-01 00:07:00  0.446200    0.008633   0.454833  0.002133
# 8       2016-01-01 00:08:00  0.432667    0.008567   0.441233  0.002133
# 9       2016-01-01 00:09:00  0.446267    0.009617   0.455883  0.002167
# 10      2016-01-01 00:10:00  1.281033    0.010583   1.291617  0.002133
# 11      2016-01-01 00:11:00  1.594850    0.010783   1.605633  0.002167
# ...

# %%
ll =[i for i in range(0,503924,15)]

# %%
split = df.loc[ll,]

# %%
split.to_csv('/home/obin/Desktop/Project/Dataset/Electrical/HomeF/2016/Resultmeter2.csv',index=False)
