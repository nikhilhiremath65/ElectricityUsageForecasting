# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv('/home/obin/Desktop/Project/Dataset/Electrical/meter1_comb.csv')
df2 = pd.read_csv('/home/obin/Desktop/Project/Dataset/Electrical/meter2_comb.csv',usecols= [1,2])

# %%
df1.head()
# Out:
#    Basement      Date_Time  Dishwasher_Disposal     Dryer  Family_Rm  \
# 0  0.027330  1/1/2014 0:00             0.000246  0.002213   0.304094
# 1  0.027342  1/1/2014 0:15             0.000314  0.002040   0.043957
# 2  0.027301  1/1/2014 0:30             0.000008  0.002329   0.043480
# 3  0.027338  1/1/2014 0:45             0.000263  0.002049   0.043203
# 4  0.027307  1/1/2014 1:00             0.000258  0.002213   0.043263
#
#    Front_Bdrm   Furnace  Generation  Guest_Bdrm_SmkDet  Kit_Half_Bath_Foyer  \
# 0    0.000096  0.008474    0.009264           0.015911             0.016791
# 1    0.000070  0.008633    0.009904           0.016907             0.016817
# 2    0.000124  0.008059    0.010133           0.015923             0.016812
# 3    0.000076  0.008511    0.010029           0.015803             0.016810
# 4    0.000068  0.008500    0.010038           0.015882             0.016826
#
#        ...        Phase_A   Phase_B  Refrigerator     Solar     Usage  \
# ...

# %%
df2.head()
# Out:
#    Garage_East  Garage_West
# 0     0.000007     0.000118
# 1     0.000008     0.000118
# 2     0.000009     0.000117
# 3     0.000009     0.000118
# 4     0.000009     0.000118

# %%
df = pd.concat([df1,df2],axis= 1)

# %%
df.shape
# Out:
# (105216, 26)

# %%
df.head()
# Out:
#    Basement      Date_Time  Dishwasher_Disposal     Dryer  Family_Rm  \
# 0  0.027330  1/1/2014 0:00             0.000246  0.002213   0.304094
# 1  0.027342  1/1/2014 0:15             0.000314  0.002040   0.043957
# 2  0.027301  1/1/2014 0:30             0.000008  0.002329   0.043480
# 3  0.027338  1/1/2014 0:45             0.000263  0.002049   0.043203
# 4  0.027307  1/1/2014 1:00             0.000258  0.002213   0.043263
#
#    Front_Bdrm   Furnace  Generation  Guest_Bdrm_SmkDet  Kit_Half_Bath_Foyer  \
# 0    0.000096  0.008474    0.009264           0.015911             0.016791
# 1    0.000070  0.008633    0.009904           0.016907             0.016817
# 2    0.000124  0.008059    0.010133           0.015923             0.016812
# 3    0.000076  0.008511    0.010029           0.015803             0.016810
# 4    0.000068  0.008500    0.010038           0.015882             0.016826
#
#       ...       Refrigerator     Solar     Usage  Washing_Machine  \
# ...

# %%
df.to_csv('/home/obin/Desktop/Project/Dataset/Electrical/electric_final.csv',index=False)
